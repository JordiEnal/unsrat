# %% [markdown]
# # state of the art

# %% [markdown]
# # 4 functions of CPU

# %%
from IPython.display import Image
Image(filename="4functioncpu.JPG", width=400, height=400)

# %% [markdown]
# # Priority : for fast coding, fast processor

# %%
from IPython.display import Image
Image(filename="cpumemoryio.JPG", width=400, height=400)

# %% [markdown]
# # Storage HDD vs SSD

# %%
from IPython.display import Image
Image(filename="hddssd.png", width=400, height=400)

# %% [markdown]
# # CPU vs GPU speed

# %%
from IPython.display import Image
Image(filename="cpugpu.png", width=400, height=400)

# %% [markdown]
# # Display Resolution

# %%
from IPython.display import Image
Image(filename="hd4k8k.jpg", width=400, height=400)

# %% [markdown]
# # Laptop for Coding

# %%
from IPython.display import Image
Image(filename="laptop3.JPG", width=400, height=400)

# %% [markdown]
# # Tugas 1 Buat
