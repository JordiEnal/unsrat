# %% [markdown]
# # state of the art

# %% [markdown]
# Arithmetic Logic Unit (ALU),
# Control Unit (CU), Memory unit,
# Input/Output (I/O) Controller,
# Bus System

# %% [markdown]
# # 4 functions of CPU

# %%
from IPython.display import Image
Image(filename="4functioncpu.JPG", width=400, height=400)
